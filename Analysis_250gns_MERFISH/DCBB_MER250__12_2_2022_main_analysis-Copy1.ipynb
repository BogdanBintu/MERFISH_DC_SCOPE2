# %%
import numpy as np,os,sys,glob
import matplotlib.pylab as plt
from ioMicro import *

asm = analysis_smFISH(data_folders = [r'\\132.239.197.16\Raw_data_2\DCBB_MER250__12_2_2022',r'\\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022'],
                 save_folder = r'\\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022_Analysis',
                 H0folder=  r'\\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H1_*',exclude_H0=False)
fl_save = r'\\132.239.197.16\Raw_data_2\DCBB_MER250__12_2_2022\psf_Scope3_60x_cy5_final.pkl'
dic_psf = pickle.load(open(fl_save,'rb'))
sets = np.unique(['_set'+os.path.basename(fld).split('_set')[-1] for fld in asm.Qfolders if '_set' in os.path.basename(fld)])
print(list(sets))

def process_fov(ifov):
    asm.set_fov(ifov)
    if False:
        final_segmentation(asm.fl_bk,
                            analysis_folder=asm.save_folder,
                            plt_val=True,
                            rescz = 6,trimz=2, resc=6,p99=650)
    for iQ in range(nQs):

        asm.set_hybe(iQ)

        completed = asm.check_finished_file()
        if not completed:
            asm.get_background(force=False)
            asm.get_signal()
            asm.compute_drift(sz=300)
            #asm.get_aligned_ims()
            #imf = asm.im_sig__/asm.im_bk__
            resc=5
            #asm.im_ration = np.array([norm_slice(im_,s=30)/np.median(np.abs(im_[::resc,::resc,::resc])) for im_ in asm.im_sig_])
            #asm.im_ration = np.array([norm_slice(im_,s=30)/np.median(np.abs(im_[::resc,::resc,::resc])) for im_ in asm.im_sig_])
            
            asm.dic_th = {0:1.25,1:0.5,2:1.25}
            asm.get_Xh(th = 3,dic_psf=dic_psf)
            asm.save_fits(plt_val=False)
            
            
            
from tqdm import tqdm
asm.set_set('_set2')
nfovs = len(asm.fls_bk_)
nQs = len([fld for fld in asm.Qfolders if asm.set_ in fld])
print(nfovs,nQs)

for ifov in tqdm(np.arange(nfovs)):
    process_fov(ifov)
# Out:
# Found files:1220
# Found hybe folders:44
# ['_set1', '_set2', '_set3', '_set4']
# 312 11
#  59%|███████████████████████████████████████████████▏                                | 184/312 [00:13<00:04, 26.55it/s]
# ### define H0 and load background
# Background file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H1_set2\Conv_zscan__188.zarr
# ### load signal
# Signal file: \\132.239.197.16\Raw_data_2\DCBB_MER250__12_2_2022\H0_PTB_set2\Conv_zscan__188.zarr
#  59%|███████████████████████████████████████████████▏                                | 184/312 [00:32<00:04, 26.55it/s]
# Found drift:[   8 -169   11]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H0_set2\Conv_zscan__188.zarr
# Found drift:[-1  0  7]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H1_set2\Conv_zscan__188.zarr
# Found drift:[0 0 0]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H2_set2\Conv_zscan__188.zarr
# Found drift:[-3 -2  2]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H3_set2\Conv_zscan__188.zarr
# Found drift:[-1 -2  3]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H4_set2\Conv_zscan__188.zarr
# Found drift:[-4 -4  3]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H5_set2\Conv_zscan__188.zarr
# Found drift:[-2  0  0]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H6_set2\Conv_zscan__188.zarr
# Found drift:[ 0 -8  4]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H7_set2\Conv_zscan__188.zarr
# Found drift:[-3 -1  3]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H8_set2\Conv_zscan__188.zarr
# Found drift:[ 0 -6  7]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H9_ASO_set2\Conv_zscan__188.zarr
# Found drift:[ 0  7 28]
#  61%|███████████████████████████████████████████████▎                              | 189/312 [19:25<1:24:35, 41.26s/it]
# ### define H0 and load background
# Background file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H1_set2\Conv_zscan__189.zarr
# ### load signal
# Signal file: \\132.239.197.16\Raw_data_2\DCBB_MER250__12_2_2022\H0_PTB_set2\Conv_zscan__189.zarr
# Found drift:[  10 -169   12]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H0_set2\Conv_zscan__189.zarr
# Found drift:[-5 -3 10]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H1_set2\Conv_zscan__189.zarr
# Found drift:[0 0 0]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H2_set2\Conv_zscan__189.zarr
# Found drift:[-3 -4  1]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H3_set2\Conv_zscan__189.zarr
# Found drift:[-1 -3  2]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H4_set2\Conv_zscan__189.zarr
# Found drift:[-4 -6  3]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H5_set2\Conv_zscan__189.zarr
# Found drift:[-4 -3  0]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H6_set2\Conv_zscan__189.zarr
# Found drift:[ -2 -10   3]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H7_set2\Conv_zscan__189.zarr
# Found drift:[-5 -3  3]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H8_set2\Conv_zscan__189.zarr
# Found drift:[ -1 -11   7]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H9_ASO_set2\Conv_zscan__189.zarr
# Found drift:[-3  0 27]
#  61%|███████████████████████████████████████████████▍                              | 190/312 [37:07<3:04:45, 90.87s/it]
# ### define H0 and load background
# Background file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H1_set2\Conv_zscan__190.zarr
# ### load signal
# Signal file: \\132.239.197.16\Raw_data_2\DCBB_MER250__12_2_2022\H0_PTB_set2\Conv_zscan__190.zarr
# Found drift:[   9 -168   14]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H0_set2\Conv_zscan__190.zarr
# Found drift:[-2 -2  6]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H1_set2\Conv_zscan__190.zarr
# Found drift:[0 0 0]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H2_set2\Conv_zscan__190.zarr
# Found drift:[-3 -4  2]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H3_set2\Conv_zscan__190.zarr
# Found drift:[ 0 -5  2]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H4_set2\Conv_zscan__190.zarr
# Found drift:[-3 -7  5]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H5_set2\Conv_zscan__190.zarr
# Found drift:[-2 -5  0]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H6_set2\Conv_zscan__190.zarr
# Found drift:[  0 -12   6]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H7_set2\Conv_zscan__190.zarr
# Found drift:[-3 -4  2]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H8_set2\Conv_zscan__190.zarr
# Found drift:[  0 -10   8]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H9_ASO_set2\Conv_zscan__190.zarr
# Found drift:[-2  1 29]
#  61%|███████████████████████████████████████████████▏                             | 191/312 [55:16<5:14:01, 155.71s/it]
# ### define H0 and load background
# Background file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H1_set2\Conv_zscan__191.zarr
# ### load signal
# Signal file: \\132.239.197.16\Raw_data_2\DCBB_MER250__12_2_2022\H0_PTB_set2\Conv_zscan__191.zarr
# Found drift:[   9 -168   14]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H0_set2\Conv_zscan__191.zarr
# Found drift:[-4  0  6]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H1_set2\Conv_zscan__191.zarr
# Found drift:[0 0 0]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H2_set2\Conv_zscan__191.zarr
# Found drift:[-3 -2  2]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H3_set2\Conv_zscan__191.zarr
# Found drift:[ 0 -2  2]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H4_set2\Conv_zscan__191.zarr
# Found drift:[-3 -4  4]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H5_set2\Conv_zscan__191.zarr
# Found drift:[-3  0  0]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H6_set2\Conv_zscan__191.zarr
# Found drift:[  0 -10   5]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H7_set2\Conv_zscan__191.zarr
# Found drift:[-3 -2  3]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H8_set2\Conv_zscan__191.zarr
# Found drift:[ 0 -7  7]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H9_ASO_set2\Conv_zscan__191.zarr
# Found drift:[-1  3 30]
#  62%|██████████████████████████████████████████████▏                            | 192/312 [1:13:08<7:47:07, 233.56s/it]
# ### define H0 and load background
# Background file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H1_set2\Conv_zscan__192.zarr
# ### load signal
# Signal file: \\132.239.197.16\Raw_data_2\DCBB_MER250__12_2_2022\H0_PTB_set2\Conv_zscan__192.zarr
# Found drift:[   8 -170   14]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H0_set2\Conv_zscan__192.zarr
# Found drift:[-2  0  6]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H1_set2\Conv_zscan__192.zarr
# Found drift:[0 0 0]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H2_set2\Conv_zscan__192.zarr
# Found drift:[-3 -3  1]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H3_set2\Conv_zscan__192.zarr
# Found drift:[-1 -4  0]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H4_set2\Conv_zscan__192.zarr
# Found drift:[-3 -6  0]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H5_set2\Conv_zscan__192.zarr
# Found drift:[-2 -2  0]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H6_set2\Conv_zscan__192.zarr
# Found drift:[  0 -11   6]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H7_set2\Conv_zscan__192.zarr
# Found drift:[-4 -2  0]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H8_set2\Conv_zscan__192.zarr
# Found drift:[ 0 -6  6]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H9_ASO_set2\Conv_zscan__192.zarr
# Found drift:[-3  7 29]
#  62%|█████████████████████████████████████████████▊                            | 193/312 [1:31:33<10:50:11, 327.83s/it]
# ### define H0 and load background
# Background file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H1_set2\Conv_zscan__193.zarr
# ### load signal
# Signal file: \\132.239.197.16\Raw_data_2\DCBB_MER250__12_2_2022\H0_PTB_set2\Conv_zscan__193.zarr
# Found drift:[   8 -168   12]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H0_set2\Conv_zscan__193.zarr
# Found drift:[-3  0  7]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H1_set2\Conv_zscan__193.zarr
# Found drift:[0 0 0]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H2_set2\Conv_zscan__193.zarr
# Found drift:[-4 -3  2]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H3_set2\Conv_zscan__193.zarr
# Found drift:[-2 -3  3]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H4_set2\Conv_zscan__193.zarr
# Found drift:[-3 -4  4]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H5_set2\Conv_zscan__193.zarr
# Found drift:[-2 -1  2]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H6_set2\Conv_zscan__193.zarr
# Found drift:[ 0 -9  8]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H7_set2\Conv_zscan__193.zarr
# Found drift:[-3 -3  1]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H8_set2\Conv_zscan__193.zarr
# Found drift:[ 0 -7  6]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H9_ASO_set2\Conv_zscan__193.zarr
# Found drift:[-3  5 27]
#  62%|██████████████████████████████████████████████                            | 194/312 [1:51:13<14:29:09, 441.95s/it]
# ### define H0 and load background
# Background file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H1_set2\Conv_zscan__194.zarr
# ### load signal
# Signal file: \\132.239.197.16\Raw_data_2\DCBB_MER250__12_2_2022\H0_PTB_set2\Conv_zscan__194.zarr
# Found drift:[   9 -168   12]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H0_set2\Conv_zscan__194.zarr
# Found drift:[-2 -5  7]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H1_set2\Conv_zscan__194.zarr
# Found drift:[0 0 0]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H2_set2\Conv_zscan__194.zarr
# Found drift:[-3 -4  2]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H3_set2\Conv_zscan__194.zarr
# Found drift:[ 0 -5  2]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H4_set2\Conv_zscan__194.zarr
# Found drift:[-2 -7  1]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H5_set2\Conv_zscan__194.zarr
# Found drift:[-2 -5 -1]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H6_set2\Conv_zscan__194.zarr
# Found drift:[  0 -13   3]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H7_set2\Conv_zscan__194.zarr
# Found drift:[-3 -7  0]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H8_set2\Conv_zscan__194.zarr
# Found drift:[  0 -12   5]
# ### define H0 and load background
# ### load signal
# Signal file: \\132.239.200.33\Raw_data\DCBB_MER250__12_2_2022\H9_ASO_set2\Conv_zscan__194.zarr
# Found drift:[ 0  0 27]
# 100%|██████████████████████████████████████████████████████████████████████████████| 312/312 [2:09:44<00:00, 24.95s/it]
